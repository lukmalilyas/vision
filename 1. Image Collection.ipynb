# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip install opencv-python

# %%
# Import opencv
import cv2 

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

# %% [markdown]
# # 2. Define Images to Collect

# %%
labels = ['Spaghetti', 'Olive_oil', 'Garlic', 'Red_pepper_flakes', 'Parsley']
labels = ['Tomatoes', 'Mozzarella', 'Basil_leaves', 'Balsamic_glaze', 'Olive_oil']
labels = ['Chicken_breast', 'Bell_pepper', 'Broccoli', 'Carrot', 'Soy_sauce', 'Ginger', 'Garlic']
labels = ['Tortillas', 'Beans', 'Corn', 'Cheese', 'Salsa']
labels = ['Pasta', 'Zucchini, Tomatoes, Bell_pepper', 'Olive_oil', 'Cheese']
labels = ['Egg', 'Milk', 'Cheese']
labels = ['Baguette', 'Tomatoes', 'Basil_leaves', 'Garlic', 'Olive oil']
labels = ['Rice', 'Mushroom', 'Onion', 'Chicken', 'Cheese']
labels = ['Chicken', 'Dijon_mustard', 'Honey']
labels = ['Tuna', 'Mayonnaise', 'Celery', 'Lettuce', 'Tortillas']
labels = ['Lettuce']
number_imgs = 5

# %%
print(labels)
# Out:
# ['Lettuce']

# %%
# Define all the label lists
labels_1 = ['Spaghetti', 'Olive_oil', 'Garlic', 'Red_pepper_flakes', 'Parsley']
labels_2 = ['Tomatoes', 'Mozzarella', 'Basil_leaves', 'Balsamic_glaze', 'Olive_oil']
labels_3 = ['Chicken_breast', 'Bell_pepper', 'Broccoli', 'Carrot', 'Soy_sauce', 'Ginger', 'Garlic']
labels_4 = ['Tortillas', 'Beans', 'Corn', 'Cheese']
labels_5 = ['Pasta', 'Zucchini', 'Tomatoes', 'Bell_pepper', 'Olive_oil', 'Cheese']
labels_6 = ['Egg', 'Milk', 'Cheese']
labels_7 = ['Baguette', 'Tomatoes', 'Basil_leaves', 'Garlic', 'Olive_oil']
labels_8 = ['Rice', 'Mushroom', 'Onion', 'Chicken_breast', 'Cheese']
labels_9 = ['Chicken_breast', 'Dijon_mustard', 'Honey']
labels_10 = ['Tuna', 'Mayonnaise', 'Celery', 'Lettuce', 'Tortillas']

# Create an empty list to store all labels
all_labels = []

# Add labels from each list to the all_labels list
all_labels.extend(labels_1)
all_labels.extend(labels_2)
all_labels.extend(labels_3)
all_labels.extend(labels_4)
all_labels.extend(labels_5)
all_labels.extend(labels_6)
all_labels.extend(labels_7)
all_labels.extend(labels_8)
all_labels.extend(labels_9)
all_labels.extend(labels_10)

print(len(all_labels))

# Remove duplicates by converting to a set and back to a list
all_labels = list(set(all_labels))

# Print the combined list of labels
print(all_labels)
# Out:
# 48
# ['Carrot', 'Corn', 'Dijon_mustard', 'Egg', 'Basil_leaves', 'Honey', 'Balsamic_glaze', 'Mozzarella', 'Cheese', 'Onion', 'Zucchini', 'Spaghetti', 'Parsley', 'Rice', 'Pasta', 'Broccoli', 'Milk', 'Chicken_breast', 'Olive_oil', 'Beans', 'Red_pepper_flakes', 'Mushroom', 'Tortillas', 'Lettuce', 'Garlic', 'Mayonnaise', 'Tuna', 'Baguette', 'Tomatoes', 'Celery', 'Bell_pepper', 'Ginger', 'Soy_sauce']

# %% [markdown]
# # 3. Setup Folders

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# # 4. Capture Images

# %%
import cv2
import numpy as np
import tensorflow as tf
import pyttsx3
import urllib.request
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
import time
import os
import uuid

URL = "http://192.168.1.4:8080/shot.jpg"
cv2.namedWindow('frame', cv2.WINDOW_NORMAL)
cv2.resizeWindow('frame', 100, 100)  # Set a small size for the window

for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        print('Collecting image {}'.format(imgnum))
        img_arr = np.array(bytearray(urllib.request.urlopen(URL).read()), dtype=np.uint8)
        frame = cv2.imdecode(img_arr, -1)
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cv2.destroyAllWindows()

# %% [markdown]
# # 5. Image Labelling

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# ...
#      ---------------------------------------- 0.0/50.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/50.1 MB ? eta -:--:--
#      --------------------------------------- 0.0/50.1 MB 435.7 kB/s eta 0:01:55
#      ---------------------------------------- 0.1/50.1 MB 1.1 MB/s eta 0:00:46
#      ---------------------------------------- 0.3/50.1 MB 2.0 MB/s eta 0:00:26
#      ---------------------------------------- 0.6/50.1 MB 3.3 MB/s eta 0:00:16
#       --------------------------------------- 0.9/50.1 MB 3.9 MB/s eta 0:00:13
#       --------------------------------------- 1.0/50.1 MB 3.6 MB/s eta 0:00:14
#       --------------------------------------- 1.1/50.1 MB 3.2 MB/s eta 0:00:16
#       --------------------------------------- 1.1/50.1 MB 3.2 MB/s eta 0:00:16
#       --------------------------------------- 1.1/50.1 MB 3.2 MB/s eta 0:00:16
#      - -------------------------------------- 1.3/50.1 MB 2.7 MB/s eta 0:00:19
# ...

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}
# Out:
# Cloning into 'Tensorflow\labelimg'...

# %%
if os.name == 'posix':
    # !make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# ^C

# %%
python --version

# %% [markdown]
# # 6. Move them into a Training and Testing Partition

# %% [markdown]
# # OPTIONAL - 7. Compress them for Colab Training

# %%
import os
TRAIN_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'train')
TEST_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'test')
ARCHIVE_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'archive.tar.gz')

# %%
# !tar -czf {ARCHIVE_PATH} {TRAIN_PATH} {TEST_PATH}
